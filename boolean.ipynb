# %% [markdown]
# A Boolean represents True or False.

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %% [markdown]
# auto typecast true = 1 and false = 0 and give result for arithmetic operations

# %%
print(True * True)
print(True * False)
# Out:
# 1
# 0

# %% [markdown]
# comparison operators > < = !

# %%
print(5 > 3)
print(6 < 2)
print(5 >= 7)
print(5 != 5)
print(5 >= 3)
# Out:
# True
# False
# False
# False
# True

# %% [markdown]
# logical operators (and, or, not)

# %%
print(1 and 1)
print(0 and 0)
print(0 and 1)
print(1 and 0)
# Out:
# 1
# 0
# 0
# 0

# %%
print(1 or 1)
print(0 or 0)
print(0 or 1)
print(1 or 0)
# Out:
# 1
# 0
# 1
# 1

# %%
print(not 0)
print(not 1)
# Out:
# True
# False

# %%
5 < 10 and 9 < 5
# Out:
# False

# %%
5 != 5 or 1 < 2
# Out:
# True

# %% [markdown]
# operator precedance -> () > not > and > or

# %%
True or False and False
# Out:
# True

# %%
(True or False) and False
# Out:
# False

# %%
not True or False
# Out:
# False

# %%
True or not False and not True
# Out:
# True

# %% [markdown]
# Truthiness and Falsiness: Values in Python can be evaluated as True or False in a Boolean context. Zero, empty strings, empty lists, and None are considered Falsy. Non-zero numbers and non-empty data structures are considered Truthy. The bool() function can be used to explicitly convert values to Boolean.

# %%
bool(0)
# Out:
# False

# %%
bool(156)
# Out:
# True

# %%
bool(-54)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool("apple")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([4, 5, 6])
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
a = 5
b = a

# %%
a is b
# Out:
# True

# %%
id(a) == id(b)
# Out:
# True

# %%
x = 9
y = 9

# %%
id(x) == id(y)
# Out:
# True

# %% [markdown]
# lists are mutable so results are different

# %%
u = [4, 5, 6]
v = [4, 5, 6]

# %%
u is v
# Out:
# False

# %%
u is not v
# Out:
# True

# %%
id(u) == id(v)
# Out:
# False
