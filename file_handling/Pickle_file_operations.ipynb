# %%
import pickle

# %%
data = {"name" : "sudh" , "adress":"fdfas"}

# %%
with open('data.pkl','wb') as f :
    pickle.dump(data,f)

# %%
l = [3,4,5,6,78,8]

# %%
with open('data1.pkl','wb') as f :
    pickle.dump(l,f)

# %%
with open('data.pkl','rb') as f :
    print(pickle.load(f))
# Out:
# {'name': 'sudh', 'adress': 'fdfas'}
